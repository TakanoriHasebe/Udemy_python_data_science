# %%
# pandasからSeries, DataFrameの読み込み
import pandas as pd
from pandas import Series, DataFrame
import numpy as np

# %%
# seabornの読み込み
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# yahoo or Googleから株価をそのままダウンロード可能
from pandas_datareader import data as web

# %%
# 日付と時刻を扱えるようになる
from datetime import datetime

# %%
# Apple, Google, Microsoft, Amazonを表示する文字列
tech_list = ['AAPL', 'GOOG', 'MSFT', 'AMZN']

# %%
# いつからのデータを扱うか
# 去年の今から今日までの株価を取得できる
end = datetime.now()
start = datetime(end.year - 1, end.month, end.day)

# %%
# DataFrame化している
for stock in tech_list:
    
    globals()[stock] = web.DataReader(stock, 'google', start, end)
# Out:
# /Users/Takanori/anaconda/lib/python3.6/site-packages/pandas_datareader/google/daily.py:40: UnstableAPIWarning:
# The Google Finance API has not been stable since late 2017. Requests seem
# to fail at random. Failure is especially common when bulk downloading.
#
#   warnings.warn(UNSTABLE_WARNING, UnstableAPIWarning)

# %%
# DataFrame化されていることが分かる
# Open : 初値, High : 一日の取引の中で一番高かった価格
# Low : １日の取引で一番低かった価格
# Close : その日の終値
# Volume : 出来高
AAPL.describe()
# Out:
#              Open        High         Low       Close        Volume
# count  249.000000  249.000000  249.000000  249.000000  2.490000e+02
# mean   163.046506  164.369116  161.726627  163.058474  3.059658e+07
# std     10.408872   10.575931   10.417904   10.476388  1.236417e+07
# min    142.900000  143.500000  142.200000  142.270000  1.402667e+07
# 25%    154.340000  155.440000  153.460000  154.450000  2.187032e+07
# 50%    162.620000  163.960000  160.520000  162.910000  2.710855e+07
# 75%    172.580000  174.170000  171.650000  172.500000  3.565584e+07
# max    182.590000  184.250000  180.210000  183.830000  8.659382e+07

# %%
AAPL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 249 entries, 2017-05-08 to 2018-05-04
# Data columns (total 5 columns):
# Open      249 non-null float64
# High      249 non-null float64
# Low       249 non-null float64
# Close     249 non-null float64
# Volume    249 non-null int64
# dtypes: float64(4), int64(1)
# memory usage: 11.7 KB

# %%
# 過去1年間のAppleの株価を可視化
AAPL['Close'].plot(legend=True, figsize=(10, 4))

# %%
AAPL['Volume'].plot(legend=True, figsize=(10, 4))

# %% [markdown]
# #### <font color='blue'>移動平均について計算をする</font>

# %% [markdown]
# 移動平均線とはグラフから、10日・20日・50日間という決まった期間を平均してグラフ化する。<br>

# %%
ma_day = [10, 20, 50]
for ma in ma_day:
    column_name = 'MA {}'.format(ma)
    # 終値に対して移動平均をとる
    AAPL[column_name] = pd.rolling_mean(AAPL['Close'], ma)
# Out:
# /Users/Takanori/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=10,center=False).mean()
#   """
# /Users/Takanori/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=20,center=False).mean()
#   """
# /Users/Takanori/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=50,center=False).mean()
#   """

# %%
AAPL.tail()
# Out:
#               Open    High     Low   Close    Volume    MA 10    MA 20  \
# Date
# 2018-04-26  164.12  165.73  163.37  164.22  27963014  170.120  170.336
# 2018-04-27  164.00  164.33  160.63  162.32  35655839  168.879  170.063
# 2018-04-30  162.13  167.26  161.84  165.26  42427424  167.823  169.992
# 2018-05-03  175.88  177.50  174.44  176.89  34068180  167.688  170.417
# 2018-05-04  178.25  184.25  178.17  183.83  56201317  168.287  171.028
#
#                MA 50
# Date
# 2018-04-26  172.8510
# 2018-04-27  172.7500
# 2018-04-30  172.5954
# 2018-05-03  172.6846
# 2018-05-04  172.9242

# %%
AAPL[['Close', 'MA 10', 'MA 20', 'MA 50']].plot(subplots=False, figsize=(10, 4))

# %%
# 株価できになるのは終値を昨日の終値と比較したもの
# pct_changeでそれぞれを比較して、どれくらい変化したかを調べる
AAPL['Daily Return'] = AAPL['Close'].pct_change()

# %%
AAPL.head()
# Out:
#               Open    High     Low   Close    Volume  MA 10  MA 20  MA 50  \
# Date
# 2017-05-08  149.03  153.70  149.03  153.01  48752413    NaN    NaN    NaN
# 2017-05-09  153.87  154.88  153.45  153.99  39130363    NaN    NaN    NaN
# 2017-05-10  153.63  153.94  152.11  153.26  25805692    NaN    NaN    NaN
# 2017-05-11  152.45  154.07  152.31  153.95  27255058    NaN    NaN    NaN
# 2017-05-12  154.70  156.42  154.67  156.10  32527017    NaN    NaN    NaN
#
#             Daily Return
# Date
# 2017-05-08           NaN
# 2017-05-09      0.006405
# 2017-05-10     -0.004741
# 2017-05-11      0.004502
# 2017-05-12      0.013966

# %%
# 前日と比べてどれくらい変化したかが分かるグラフが可視化
AAPL['Daily Return'].plot(figsize=(10, 4), legend=True, linestyle='--', marker='o')

# %%
# ヒストグラムを作成する
sns.distplot(AAPL['Daily Return'].dropna(), bins = 100, color='purple')

# %%
AAPL['Daily Return'].hist(bins=100)

# %%
# データをとってくる
closing_df = web.DataReader(['AAPL', 'GOOG', 'MSFT', 'AMZN'], 'google', start, end)['Close']
# Out:
# /Users/Takanori/anaconda/lib/python3.6/site-packages/pandas_datareader/google/daily.py:40: UnstableAPIWarning:
# The Google Finance API has not been stable since late 2017. Requests seem
# to fail at random. Failure is especially common when bulk downloading.
#
#   warnings.warn(UNSTABLE_WARNING, UnstableAPIWarning)

# %%
closing_df.head()
# Out:
#               AAPL    AMZN    GOOG   MSFT
# Date
# 2017-05-08  153.01  949.04  934.30  68.94
# 2017-05-09  153.99  952.82  932.17  69.04
# 2017-05-10  153.26  948.95  928.78  69.31
# 2017-05-11  153.95  947.62  930.60  68.46
# 2017-05-12  156.10  961.35  932.22  68.38

# %%
# 終値のパーセンテージで表示
tech_rets = closing_df.pct_change()

# %%
tech_rets
# Out:
#                 AAPL      AMZN      GOOG      MSFT
# Date
# 2017-05-08       NaN       NaN       NaN       NaN
# 2017-05-09  0.006405  0.003983 -0.002280  0.001451
# 2017-05-10 -0.004741 -0.004062 -0.003637  0.003911
# 2017-05-11  0.004502 -0.001402  0.001960 -0.012264
# 2017-05-12  0.013966  0.014489  0.001741 -0.001169
# 2017-05-15 -0.002562 -0.003516  0.005213  0.000731
# 2017-05-16 -0.001477  0.008455  0.006317  0.014321
# 2017-05-17 -0.033576 -0.022058 -0.024793 -0.027806
# 2017-05-18  0.015241  0.014533  0.011548  0.003408
# 2017-05-19  0.003409  0.001408  0.004053 -0.000295
# 2017-05-22  0.006076  0.011283  0.008405  0.011228
# 2017-05-23 -0.001234  0.000896  0.007390  0.003360
# 2017-05-24 -0.002991  0.009068  0.006471  0.001310
# 2017-05-25  0.003456  0.013291  0.015268  0.012360
# 2017-05-26 -0.001690  0.002416  0.001991  0.004884
# 2017-05-30  0.000391  0.000924  0.004540  0.006432
# 2017-05-31 -0.005922 -0.002087 -0.011292 -0.008095
# 2017-06-01  0.002749  0.001337  0.002166  0.003723
# 2017-06-02  0.014819  0.010824  0.008946  0.023680
# 2017-06-05 -0.009778  0.004579  0.008282  0.007246
# 2017-06-06  0.003378 -0.008246 -0.007228  0.003320
# 2017-06-07  0.005957  0.007049  0.004618 -0.001793
# 2017-06-08 -0.002446  0.000198  0.002375 -0.006078
# 2017-06-09 -0.038777 -0.031635 -0.034146 -0.022655
# 2017-06-12 -0.023896 -0.013697 -0.007296 -0.007679
# 2017-06-13  0.008046  0.016457  0.011136  0.012468
# 2017-06-14 -0.009755 -0.004405 -0.002769 -0.005379
# 2017-06-15 -0.005993 -0.012596 -0.008888 -0.005265
# 2017-06-16 -0.014000  0.024415 -0.002685  0.001431
# 2017-06-19  0.028608  0.007553  0.018717  0.012429
# ...              ...       ...       ...       ...
# 2018-03-21 -0.022655 -0.002931 -0.006222 -0.006979
# 2018-03-22 -0.014130 -0.023352 -0.038318 -0.029087
# 2018-03-23 -0.023157 -0.031950 -0.026223 -0.029068
# 2018-03-26  0.047472  0.040319  0.030972  0.075705
# 2018-03-27 -0.025641 -0.037799 -0.045679 -0.045959
# 2018-03-28 -0.011049 -0.043840 -0.000537 -0.000894
# 2018-03-29  0.007809  0.011122  0.027106  0.021031
# 2018-04-02 -0.006556 -0.052061 -0.024540 -0.030130
# 2018-04-03  0.010259  0.014621  0.006895  0.013443
# 2018-04-04  0.019122  0.013304  0.011575  0.029205
# 2018-04-05  0.006934  0.029194  0.002605  0.000542
# 2018-04-06 -0.025579 -0.032044 -0.020208 -0.023273
# 2018-04-09  0.009918  0.000605  0.008351  0.005985
# 2018-04-10  0.018818  0.021435  0.015944  0.023246
# 2018-04-11 -0.004675 -0.006385 -0.011312 -0.010982
# 2018-04-12  0.009859  0.015031  0.012294  0.018724
# 2018-04-13  0.003388 -0.012226 -0.003138 -0.005343
# 2018-04-16  0.006238  0.007485  0.008462  0.011710
# 2018-04-17  0.013764  0.043240  0.034856  0.020176
# 2018-04-18 -0.002244  0.015966 -0.001936  0.003851
# 2018-04-19 -0.028340  0.019027  0.014570 -0.003422
# 2018-04-20 -0.040972 -0.018896 -0.013552 -0.011549
# 2018-04-23 -0.002896 -0.006304 -0.005135  0.003684
# 2018-04-24 -0.013919 -0.038060 -0.044470 -0.023388
# 2018-04-25  0.004357  0.000055  0.001176 -0.008698
# 2018-04-26  0.003483  0.039578  0.018469  0.021124
# 2018-04-27 -0.011570  0.036009 -0.009605  0.016550
# 2018-04-30  0.018112 -0.004127 -0.012349 -0.024003
# 2018-05-03  0.070374  0.003799  0.006281  0.005881
# 2018-05-04  0.039233  0.005642  0.023923  0.011587
#
# [249 rows x 4 columns]

# %%
# 相関係数を算出している
sns.jointplot('GOOG', 'GOOG', tech_rets, kind = 'scatter', color = 'seagreen')

# %%
# microsoftとの相関係数を算出する
sns.jointplot('GOOG', 'MSFT', tech_rets, kind = 'scatter', color = 'seagreen')

# %%
# 4社分のデータに対して、いっぺんに散布図を書く
sns.pairplot(tech_rets.dropna())

# %%
# 上側と下側のグラフを変更する。
returns_fig = sns.PairGrid(tech_rets.dropna())
# 各図の指定
returns_fig.map_upper(plt.scatter, color='purple')
returns_fig.map_lower(sns.kdeplot, cmap='cool_d')
returns_fig.map_diag(plt.hist, bins=30)

# %% [markdown]
# 上記から対角線上にヒストグラムが並んでいて<br>
# 右上に散布図が並んでいる。<br>
# 左下にカーネル密度関数が表示されている。<br>

# %%
# 上側と下側のグラフを変更する。
returns_fig = sns.PairGrid(closing_df)
# 各図の指定
returns_fig.map_upper(plt.scatter, color='purple')
returns_fig.map_lower(sns.kdeplot, cmap='cool_d')
returns_fig.map_diag(plt.hist, bins=30)

# %%
# 相関係数を数字として求めて、それをそのままプロットする
sns.heatmap(tech_rets.corr(), annot=True)

# %%
sns.heatmap(closing_df.corr(), annot=True)

# %% [markdown]
# 上記からどこかの株価が上がれば、また別の株価も上がることが分かる。<br>
