# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
# タイタニック号のcsvを読み込み
titanic_df = pd.read_csv('train.csv')

# %%
# 先頭をみる
# Survived : 生還, Pclass : 客室, Name : 名前, Sex : 性別
# Age : 年齢, SibSp : 兄弟姉妹の有無, Parch : 親もしくは子供と一緒
# Ticket : チケット, Fare : 値段, Cabin : 当時いたところ, Embarked : 乗り込んだ港

titanic_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# 以下を見るとAge, CabinのデータがNULLが多いことが分かる。
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# ## <font color=blue>上記の情報から以下のことを実行する</font>

# %% [markdown]
# 1. タイタニック号の乗客はどのような人であったか。
# 2. それぞれの乗客はどのデッキにいたか？また、それは客室の種類とどのような関係にあったか。
# 3. 乗客は主にどこから来たか?
# 4. 家族連れか、単身者か？<br>
# <font color = 'red'>宿題として以下のことを実行する。</font><br>
# 5. 沈没からの生還者には、どのような要因があったか

# %% [markdown]
# ## <font color='blue'>まずは自分で1.について実行する</font>

# %% [markdown]
# ### <font color = 'blue'>性別についてのグラフを作成する</font>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# 棒グラフ
sns.countplot(x="Pclass", data=titanic_df)

# %%
titanic_df_temp = pd.read_csv('train.csv')

# %%
titanic_df_temp.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# 以下から乗客は男性が多いことが分かる。
sns.countplot(x = 'Sex', data = titanic_df)

# %%
sns.countplot(x = 'Survived', data = titanic_df)

# %%
# 男女をPclassで分ける
sns.countplot('Sex', data = titanic_df, hue = 'Pclass')

# %%
# 3等客室は男性の方が多いことが分かる
sns.countplot('Pclass', data = titanic_df, hue = 'Sex')

# %% [markdown]
# ### <font color='blue'>ある年齢よりも小さい場合には子供とし可視化（自分）</font>

# %%
titanic_df_temp.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df_temp['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
# 8      27.0
# 9      14.0
# 10      4.0
# 11     58.0
# 12     20.0
# 13     39.0
# 14     14.0
# 15     55.0
# 16      2.0
# 17      NaN
# 18     31.0
# 19      NaN
# 20     35.0
# 21     34.0
# 22     15.0
# 23     28.0
# 24      8.0
# 25     38.0
# 26      NaN
# 27     19.0
# 28      NaN
# 29      NaN
#        ...
# 861    21.0
# 862    48.0
# 863     NaN
# 864    24.0
# 865    42.0
# 866    27.0
# 867    31.0
# 868     NaN
# 869     4.0
# 870    26.0
# 871    47.0
# 872    33.0
# 873    47.0
# 874    28.0
# 875    15.0
# 876    20.0
# 877    19.0
# 878     NaN
# 879    56.0
# 880    25.0
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %% [markdown]
# ### <font color='blue'>答え</font>

# %%
titanic_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# DataFrameを関数に適用している。
def male_female_child(passenger):
    age, sex = passenger
    if age < 16:
        return 'child'
    else:
        return sex
    
titanic_df['person'] = titanic_df[['Age', 'Sex']].apply(male_female_child, axis=1)

# %%
# titanic_dfに新しい列ができている
titanic_df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
sns.countplot('Pclass', data=titanic_df, hue='person')

# %%
# 度数が10になっている
titanic_df['Age'].hist(bins=10)

# %%
# 度数が70になっている
titanic_df['Age'].hist(bins=70)

# %%
# 平均をとっている
titanic_df['Age'].mean()
# Out:
# 29.69911764705882

# %%
# personに対して細かい数字をとる
titanic_df['person'].value_counts()
# Out:
# male      537
# female    271
# child      83
# Name: person, dtype: int64

# %%
titanic_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# ...

# %%
titanic_df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
# ### <font color='blue'>カーネル密度関数を用いて可視化</font>

# %%
# 性別でそうべつかしている
fig = sns.FacetGrid(titanic_df, hue='Sex', aspect=4)
# 年齢についてkdeplotを行う
fig.map(sns.kdeplot, 'Age', shade=True)
# 最高齢を選ぶ
oldest = titanic_df['Age'].max()
# 0 - 最高齢まで
fig.set(xlim=(0, oldest))
# legendを追加
fig.add_legend()

# %%
fig = sns.FacetGrid(titanic_df, hue='person', aspect=4)
fig.map(sns.kdeplot, 'Age', shade=True)
oldest = titanic_df['Age'].max()
fig.set(xlim=(0, oldest))
fig.add_legend()

# %%
fig = sns.FacetGrid(titanic_df, hue='Pclass', aspect=4)
fig.map(sns.kdeplot, 'Age', shade=True)
oldest = titanic_df['Age'].max()
fig.set(xlim=(0, oldest))
fig.add_legend()

# %% [markdown]
# ### <font color='blue'>以下からは乗っていた場所について見ていくことにする</font>

# %%
titanic_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# ...

# %%
titanic_df['Cabin'].head(5)
# Out:
# 0     NaN
# 1     C85
# 2     NaN
# 3    C123
# 4     NaN
# Name: Cabin, dtype: object

# %%
# countplotではCabinの数が多すぎて分からない
sns.countplot('Cabin', data=titanic_df)

# %%
titanic_df['Cabin'].head(10)
# Out:
# 0     NaN
# 1     C85
# 2     NaN
# 3    C123
# 4     NaN
# 5     NaN
# 6     E46
# 7     NaN
# 8     NaN
# 9     NaN
# Name: Cabin, dtype: object

# %% [markdown]
# #### <font color='blue'>最初の文字のみを取り出すという方針で進める</font>

# %%
titanic_df['Cabin'].head(10)
# Out:
# 0     NaN
# 1     C85
# 2     NaN
# 3    C123
# 4     NaN
# 5     NaN
# 6     E46
# 7     NaN
# 8     NaN
# 9     NaN
# Name: Cabin, dtype: object

# %% [markdown]
# #### <font color='blue'>答え</font>

# %%
# まずはNANを削除する
deck = titanic_df['Cabin'].dropna()

# %%
deck
# Out:
# 1              C85
# 3             C123
# 6              E46
# 10              G6
# 11            C103
# 21             D56
# 23              A6
# 27     C23 C25 C27
# 31             B78
# 52             D33
# 54             B30
# 55             C52
# 61             B28
# 62             C83
# 66             F33
# 75           F G73
# 88     C23 C25 C27
# 92             E31
# 96              A5
# 97         D10 D12
# 102            D26
# 110           C110
# 118        B58 B60
# 123           E101
# 124            D26
# 128          F E69
# 136            D47
# 137           C123
# 139            B86
# 148             F2
#           ...
# 751           E121
# 759            B77
# 763        B96 B98
# 765            D11
# 772            E77
# 776            F38
# 779             B3
# 781            B20
# 782             D6
# 789        B82 B84
# 796            D17
# 802        B96 B98
# 806            A36
# 809             E8
# 815           B102
# 820            B69
# ...

# %%
# 最初の1文字目を取得する
levels = []
for level in deck:
    levels.append(level[0])

# %%
levels
# Out:
# ['C',
#  'C',
#  'E',
#  'G',
#  'C',
#  'D',
#  'A',
#  'C',
#  'B',
#  'D',
#  'B',
#  'C',
#  'B',
#  'C',
#  'F',
#  'F',
#  'C',
#  'E',
#  'A',
#  'D',
#  'D',
#  'C',
#  'B',
#  'E',
#  'D',
#  'F',
#  'D',
#  'C',
#  'B',
#  'F',
#  'C',
#  'E',
#  'B',
#  'A',
#  'C',
#  'F',
#  'A',
#  'F',
#  'B',
#  'B',
#  'G',
#  'A',
#  'D',
#  'D',
#  'C',
#  'C',
#  'C',
#  'D',
#  'G',
#  'C',
#  'B',
#  'E',
#  'B',
#  'C',
#  'C',
#  'C',
#  'D',
#  'A',
#  'B',
#  'D',
#  'C',
#  'C',
#  'B',
#  'E',
#  'C',
#  'C',
#  'E',
#  'C',
#  'B',
#  'C',
#  'E',
#  'C',
#  'D',
#  'B',
#  'C',
#  'C',
#  'C',
#  'E',
#  'T',
#  'F',
#  'C',
#  'F',
#  'C',
#  'E',
#  'D',
#  'B',
#  'E',
#  'C',
#  'B',
#  'D',
#  'G',
#  'C',
#  'E',
#  'C',
#  'E',
#  'B',
#  'C',
#  'A',
#  'C',
#  'C',
#  'C',
#  'E',
#  'D',
#  'E',
#  'E',
#  'D',
#  'A',
#  'B',
#  'C',
#  'B',
#  'C',
#  'D',
#  'C',
#  'B',
#  'C',
#  'E',
#  'D',
#  'F',
#  'B',
#  'B',
#  'C',
#  'B',
#  'B',
#  'B',
#  'C',
# ...

# %%
# 新しいDataFrameを作成
cabin_df = DataFrame(levels)

# %%
# DataFrameに名前をつける
cabin_df.columns = ['Cabin']

# %%
# 新しいDataFrameが作成された
cabin_df
# Out:
#     Cabin
# 0       C
# 1       C
# 2       E
# 3       G
# 4       C
# 5       D
# 6       A
# 7       C
# 8       B
# 9       D
# 10      B
# 11      C
# 12      B
# 13      C
# 14      F
# 15      F
# 16      C
# 17      E
# 18      A
# 19      D
# 20      D
# 21      C
# 22      B
# 23      E
# 24      D
# 25      F
# 26      D
# 27      C
# 28      B
# 29      F
# ..    ...
# 174     E
# 175     B
# 176     B
# 177     D
# 178     E
# 179     F
# 180     B
# 181     B
# 182     D
# 183     B
# 184     D
# 185     B
# 186     A
# 187     E
# 188     B
# 189     B
# 190     E
# 191     B
# 192     E
# 193     C
# 194     C
# 195     D
# 196     E
# 197     D
# 198     A
# 199     D
# 200     B
# 201     C
# 202     B
# 203     C
#
# [204 rows x 1 columns]

# %%
# Cabinで可視化
sns.countplot('Cabin', data = cabin_df)

# %%
# Cabinで可視化
# order=sorted(set(levels))により、アルファベット順に並び替えられた
sns.countplot('Cabin', data = cabin_df, order=sorted(set(levels)))

# %%
# cabin_dfからTを取り除いた
cabin_df = cabin_df[cabin_df.Cabin != 'T']

# %%
sns.countplot('Cabin', data = cabin_df, order=sorted(set(levels)))

# %%
sns.countplot('Cabin', data = cabin_df, order=sorted(set(cabin_df.Cabin)))

# %% [markdown]
# ### <font color='blue'>乗客がどこから乗り込んだかについてみる</font>
# ### <font color='blue'>自分</font>

# %%
titanic_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# ...

# %%
# countplotでタイタニック号の乗り込んだ港を可視化
sns.countplot('Embarked', data = titanic_df)

# %% [markdown]
# #### <font color='blue'>答え</font>

# %%
# countplotでタイタニック号の乗り込んだ港を可視化
sns.countplot('Embarked', data = titanic_df, hue='Pclass')

# %% [markdown]
# ### <font color='blue'>注意事項</font>
# ### <font color='blue'>nullを自動的に弾いている</font>

# %%
from collections import Counter

# %%
Counter(titanic_df.Embarked)
# Out:
# Counter({'S': 644, 'C': 168, 'Q': 77, nan: 2})

# %% [markdown]
# ### <font color = 'blue'>家族連れか、単身者か？</font>

# %% [markdown]
# #### <font color='blue'>自分</font>

# %%
titanic_df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# countplotでタイタニック号
sns.countplot('Parch', data = titanic_df)

# %% [markdown]
# #### <font color='blue'>答え</font>

# %%
# 0であれば、一人で乗ってきたことになる。
titanic_df['Alone'] = titanic_df.Parch + titanic_df.SibSp
titanic_df['Alone']
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       0
# 5       0
# 6       0
# 7       4
# 8       2
# 9       1
# 10      2
# 11      0
# 12      0
# 13      6
# 14      0
# 15      0
# 16      5
# 17      0
# 18      1
# 19      0
# 20      0
# 21      0
# 22      0
# 23      0
# 24      4
# 25      6
# 26      0
# 27      5
# 28      0
# 29      0
#        ..
# 861     1
# 862     0
# 863    10
# 864     0
# 865     0
# 866     1
# 867     0
# 868     0
# 869     2
# 870     0
# 871     2
# 872     0
# 873     0
# 874     1
# 875     0
# 876     0
# 877     0
# 878     0
# 879     1
# 880     1
# 881     0
# 882     0
# 883     0
# 884     0
# 885     5
# 886     0
# 887     0
# 888     3
# 889     0
# 890     0
# Name: Alone, Length: 891, dtype: int64

# %%
# 0よりも大きい場合、With Familyが代入
# 0と同じであった場合、Aloneが代入
titanic_df['Alone'].loc[titanic_df['Alone'] > 0] = "With Family"
titanic_df['Alone'].loc[titanic_df['Alone'] == 0] = "Alone"
# Out:
# /Users/Takanori/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
# Aloneという列が追加されている。
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person        Alone
# 0      0         A/5 21171   7.2500   NaN        S    male  With Family
# 1      0          PC 17599  71.2833   C85        C  female  With Family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
# countplotでタイタニック号
sns.countplot('Alone', data = titanic_df)

# %% [markdown]
# ### <font color='blue'>タイタニックからの生還者の列を作成する</font>

# %%
titanic_df['Survivor'] = titanic_df.Survived.map({0 : 'no', 1 : 'yes'})

# %%
sns.countplot('Survivor', data = titanic_df)

# %%
sns.factorplot('Pclass', 'Survived', data = titanic_df, order=[1,2,3])

# %%
sns.factorplot('Pclass', 'Survived', hue='person', data = titanic_df, order=[1,2,3])

# %%
# 高齢になるほど生存率が下がっている
sns.lmplot('Age', 'Survived', data = titanic_df)

# %%
# 高齢になるほど生存率が下がっている。
# 一等客室の生存率が上がっている。
sns.lmplot('Age', 'Survived', hue='Pclass', data = titanic_df)

# %%
generations = [10,20,40,60,80]
sns.lmplot('Age', 'Survived', hue='Pclass', data = titanic_df, x_bins = generations)

# %%
sns.lmplot('Age', 'Survived', hue='Sex', data = titanic_df, x_bins = generations)
